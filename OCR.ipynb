# %%
# Tesserract is an open source text recognition (OCR) Engine
# install tesseract-ocr in Linux
# !apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 37 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (4,973 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 155047 files and directories currently installed.)
# ...

# %%
# install pytessertact using Tesserract in python 
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=e9ad2d6cf34900d88034da38f61193bc2e3f930399b572c8297fb4a348cb03dc
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# tesseract-ocr github 참조 : https://github.com/tesseract-ocr/

# %%
# 한글 지원을 traineddata 파일 복사
# !cp '/content/gdrive/MyDrive/License_Plate_Recognition/kor.traineddata' ../usr/share/tesseract-ocr/4.00/tessdata/
# !cp '/content/gdrive/MyDrive/License_Plate_Recognition/kor_best.traineddata' ../usr/share/tesseract-ocr/4.00/tessdata/
# !cp '/content/gdrive/MyDrive/License_Plate_Recognition/kor_fast.traineddata' ../usr/share/tesseract-ocr/4.00/tessdata/

# %%
# Tesseract 옵션 참조
# https://github.com/tesseract-ocr/tesseract/blob/master/doc/tesseract.1.asc

# %%
import cv2
from google.colab.patches import cv2_imshow
import pytesseract

# %%
file_name = '/content/gdrive/MyDrive/License_Plate_Recognition/txt1.JPG'
img = cv2.imread(file_name)  # 이미지를 불러옵니다.

config = ("-l eng --oem 1 --psm 11")   # Tesseract configration 설정
text = pytesseract.image_to_string(img, config=config)
# Tesseract에 의해 OCR 된 text 를 Display
print(text)
# Out:
# Why TensorFlow
#
# TensorFlow is an end-to-end open source platform for machine learning. It has a comprehensive,
#
# flexible ecosystem of tools, libraries and community resources that lets researchers push the state-
#
# of-the-art in ML and developers easily build and deploy ML powered applications.

# %%
file_name = '/content/gdrive/MyDrive/License_Plate_Recognition/txt.JPG'
img = cv2.imread(file_name)  # 이미지를 불러옵니다.

config = ("-l kor --oem 1 --psm 6")   # Tesseract configration 설정
text = pytesseract.image_to_string(img, config=config)
# Tesseract에 의해 OCR 된 text 를 Display
print(text)
# Out:
# 한국 스 타 트 업 들이 세계적인 비 대 면 트 렌 드 를 타고 해외 시 장 에서 성 장 을 이 어 나가고 있
# 다
# 하 이 떠 커 넥 트 는 자 사 가 훈 영 하 는 영상 앰 ' 아 자 르 ' 가 독일, 영국, 프랑스, 스위스, 스웨덴,
# 스페인, 이탈리아, 네덜란드 등 유럽 8 개 국 구글 앰 장터 비 게 임 앰 커뮤니케이션 부 문 에서
# 매출 1 위 를 차 지 했다고 14 일 발 표 했다, 모바일 앰 분석 사이트 앰 애 니 가 산 정 한 순위 기준
# 이다

# %%
file_name = '/content/gdrive/MyDrive/License_Plate_Recognition/txt.JPG'
img = cv2.imread(file_name)  # 이미지를 불러옵니다.

config = ("-l kor_best --oem 1 --psm 6")   # Tesseract configration 설정
text = pytesseract.image_to_string(img, config=config)
# Tesseract에 의해 OCR 된 text 를 Display
print(text)
# Out:
# 한국 스타트업들이 세계적인 비대면 트렌드를 타고 해외 시장에서 성장을 이어나가고 있
# 다
#
# 하이퍼커넥트는 자사가 훈영하는 영상 맵 '아자르'가 독일, 영국, 프랑스, 스위스, 스웨덴,
# 스페인, 이탈리아, 네덜란드 등 유럽 8개국 구글 앰 장터 비게임앰 커뮤니케이션 부문에서
# 매출 1위를 차지했다고 14윌 발표했다. 모바일 앰 분석 사이트 앰애니가 산정한 순위 기준
# 이다

# %%
file_name = '/content/gdrive/MyDrive/License_Plate_Recognition/txt.JPG'
img = cv2.imread(file_name)  # 이미지를 불러옵니다.

config = ("-l kor_fast --oem 1 --psm 6")   # Tesseract configration 설정
text = pytesseract.image_to_string(img, config=config)
# Tesseract에 의해 OCR 된 text 를 Display
print(text)
# Out:
# 한국 스타트업들이 세계적인 비대면 트렌드를 타고 해외 시장에서 성장을 이어나가고 있
# 다
#
# 하이퍼커넥트는 자사가 운영하는 영상 앰 '아자르'가 독일, 영국, 프랑스, 스위스, 스웨덴,
# 스페인, 이탈리아, 네덜란드 등 유럽 8개국 구글 앰 장터 비게임 커뮤니케이션 부문에서
# 매출 1위를 차지했다고 14일 발표했다. 모바일 앰 분석 사이트 앰애니가 산정한 순위 기준
# 이다

# %%
file_name = '/content/gdrive/MyDrive/License_Plate_Recognition/txt3.JPG'
img = cv2.imread(file_name)  # 이미지를 불러옵니다.

config = ("-l eng+kor_best --oem 1 --psm 11")   # Tesseract configration 설정
text = pytesseract.image_to_string(img, config=config)
# Tesseract에 의해 OCR 된 text 를 Display
print(text)
# Out:
# ㅠ 605 아 티 00/ 와 《6+35 의 관 계 에 관해 알 아 보 기
#
# TensorFlow2| #9] + APIE VSSS BIST SHAl7|7| Sst Keras API
#
# 표 준 을 기 반 으로 합 니 다 .&8(85 는 사용자 친 화 적 인 씨를 사 용 하여 신속한 프로
#
# 덕 션 을
#
# 토 타입 제작, 최첨단 연구 및 프로
#
# 덕 션 을
#
# 가 능 하 게 합니다.
